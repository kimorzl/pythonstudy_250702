# %%
#jupyter notebook을 이용해 dic을 jason으로 만들기 위해 양쪽에 """ """를 활용해 입력한 dic을 자체적으로 string data로 변환한다

import json

data = """
{
    "id":"01",
    "language":"python",
    "edition":"third",
    "author":"david",
    "history":
        [
            {
                "date":"2025-07-16",
                "item":"iPhone"
            },
            {
                "date":"2025-07-16",
                "item":"Android"
            }
        ]
}
""" 

json_data = json.loads(data) #json자료는 그냥 불러올 수 없기애 client와 browser를 연결해주는 매개체이기때문에 문볍 형태를 한번 인코딩 해야한다.
#print(json_data)
print(json_data["history"][0]["date"])  #json_data내에 있는 key값 history에 해당하는 0번째 인덱스 중 date의 값을 출력해라
# Out:
# 2025-07-16

# %%
import json

data = """
{
    "lastBuildDate": "Wed, 16 Jul 2025 13:21:28 +0900",
    "total": 73348,
    "start": 1,
    "display": 10,
    "items": [
        {
            "title": "브래그사과식초 유기농 천연 발효식초 <b>애사비</b> <b>애플사이다비니거</b> 473ml",
            "link": "https://smartstore.naver.com/main/products/4879081301",
            "image": "https://shopping-phinf.pstatic.net/main_8242360/82423604772.17.jpg",
            "lprice": "6800",
            "hprice": "",
            "mallName": "페퍼앤솔트",
            "productId": "82423604772",
            "productType": "2",
            "brand": "브래그",
            "maker": "브래그",
            "category1": "식품",
            "category2": "조미료",
            "category3": "식초",
            "category4": ""
        },
        {
            "title": "데니그리스 유기농사과식초 1리터 <b>애플사이다비니거</b> <b>애사비</b> 천연사과식초 드니그리스",
            "link": "https://smartstore.naver.com/main/products/6458240758",
            "image": "https://shopping-phinf.pstatic.net/main_8400274/84002741091.1.jpg",
            "lprice": "11900",
            "hprice": "",
            "mallName": "바이오트",
            "productId": "84002741091",
            "productType": "2",
            "brand": "",
            "maker": "",
            "category1": "식품",
            "category2": "조미료",
            "category3": "식초",
            "category4": ""
        },
        {
            "title": "<b>애사비</b> 스틱 핏업 <b>애플사이다비니거</b> 유기농 사과식초 자연발효 초모 고농축 30포, 1개",
            "link": "https://smartstore.naver.com/main/products/11091152067",
            "image": "https://shopping-phinf.pstatic.net/main_8863566/88635662389.3.jpg",
            "lprice": "23000",
            "hprice": "",
            "mallName": "핏업 공식스토어",
            "productId": "88635662389",
            "productType": "2",
            "brand": "핏업",
            "maker": "웰파인",
            "category1": "식품",
            "category2": "조미료",
            "category3": "식초",
            "category4": ""
        }
    ]
}
"""


json_data = json.loads(data) #json을 읽어올 수 있는 라이브러리 함수를 활용해 데이터 인코딩
print(json_data["items"][0]["title"])
# Out:
# 브래그사과식초 유기농 천연 발효식초 <b>애사비</b> <b>애플사이다비니거</b> 473ml

# %%
import requests
import pprint #prettier print라는 뜻으로, 결과값을 깔끔하게 출력해주는 lib
import openpyxl

client_id="uj7bhXzlUzE2ny9fXWzW"
client_secret="484ZofXmMQ"
#구조분해할당 튜플 활용
start, num = 1, 0
#엑셀 파일 만들기 위한 변수 지정
excel_file = openpyxl.Workbook()
#sheet찾아오기
excel_sheet = excel_file.active
#해당 시트 열의 기준값 찾아오기_B,C열에 자료를 넣어주고 열의 넓이를 100열로 해줘
excel_sheet.column_dimensions["B"].width = 100
excel_sheet.column_dimensions["C"].width = 100
#엑셀 시트에 값을 왼쪽부터 채워주길 바래
excel_sheet.append(["No","상품 명","상품 링크"])


for index in range(10):
    start_number = start + (index * 100)
    naver_open_api = "https://openapi.naver.com/v1/search/shop.json?query=일본 버스투어&display=100&start=" + str(start_number)
    #postman에 꼭 입력해야했던 header에 key, value넣는 법
    header_params = {"X-Naver-Client-Id":client_id, "X-Naver-Client-Secret":client_secret}
    res = requests.get(naver_open_api, headers=header_params)
    
    #requests로 불러온 데이터는 json함수를 활용해 별도의 인코딩 작업 없이 바로 json 형식의 데이터로 출력가능하다
    #test = res.json()
    
    #유효성 검사
    if res.status_code == 200:
        data = res.json()
        #pprint.pprint(data)
        #print(data["items"][0]["title"])
        for item in data["items"]:
            num += 1 #복합대 연산자
            excel_sheet.append([num, item["title"], item["link"]]) #excel_sheet에 num, title, link값을 넣어줘
            print(num, item["title"], item["link"])
    else:
        print("Error Code : ", res.status_code)


excel_file.save("shopping_with_일본버스투어.xlsx") #shopping_with_일본버스투어.xlsx라는 이름으로 파일명 저장해줘
excel_file.close() #데이터 저장이 모두 끝나면 파일 닫아줘
# Out:
# 1 [간식입장료포함9가지특전] <b>일본</b> 후쿠오카 유후인 벳부 다자이후 1일 <b>버스 투어</b> 유<b>투어</b><b>버스</b> https://smartstore.naver.com/main/products/2428674755
# 2 [전좌석 충전+Wi-Fi] 레트로 감성 히타 유후인 후쿠오카<b>버스투어</b> <b>일본</b>여행 와쿠와쿠4호선 https://smartstore.naver.com/main/products/10468459536
# 3 [히타오픈]<b>일본</b> 후쿠오카 히타 유후인 유후다케 벳푸 <b>버스투어</b> 라쿠<b>투어</b> https://smartstore.naver.com/main/products/10649847573
# 4 [여름시즌/매일출발] <b>일본</b> 북해도 샤코탄 오타루 1일 <b>버스투어</b> (라쿠<b>투어</b>) https://smartstore.naver.com/main/products/10149155422
# 5 [라이카 무료 사진 촬영] <b>일본</b> 여행 오사카 출발 나라 교토 <b>버스 투어</b> https://smartstore.naver.com/main/products/9200322390
# 6 [즉시확정/준페이예약] 삿포로 비에이 후라노 <b>버스 투어</b> <b>일본</b> 홋카이도 근교 여행 하루하루 https://tourvis.com/activity/product/PRD3006327406?utm_id=ttijpn2406ss3006327406&utm_source=naver&utm_medium=ss&utm_campaign=tour_int_japan&utm_content=PRD3006327406
# ...

# %%
import requests
import openpyxl

client_id = "uj7bhXzlUzE2ny9fXWzW"
client_secret = "484ZofXmMQ"

excel_file = openpyxl.Workbook()
excel_sheet = excel_file.active
excel_sheet.title = "일본여행 블로그"
excel_sheet.column_dimensions["B"].width = 30
excel_sheet.column_dimensions["C"].width = 50
excel_sheet.column_dimensions["D"].width = 80
excel_sheet.append(["No", "블로그 명", "포스팅 제목", "포스팅 링크", "업로드 날짜"])

num = 0

# 최대 1000개까지만 가능 (50개 * 20페이지)
for index in range(20):
    start_num = 1 + (index * 50)
    naver_openapi_blog = f"https://openapi.naver.com/v1/search/blog.json?query=일본여행&display=50&start={start_num}"
    header_param = {
        "X-Naver-Client-Id": client_id,
        "X-Naver-Client-Secret": client_secret
    }

    res = requests.get(naver_openapi_blog, headers=header_param)

    if res.status_code == 200:
        blog_data = res.json()
        for item in blog_data["items"]:
            num += 1
            excel_sheet.append([
                num,
                item["bloggername"],
                item["title"].replace("<b>", "").replace("</b>", ""),
                item["link"],
                item["postdate"]
            ])
            print(num, item["bloggername"], item["title"], item["link"], item["postdate"])
    else:
        print("Error Code:", res.status_code)
        break  # 에러 발생 시 반복 중단

# 엑셀 저장
excel_file.save("blog_일본여행.xlsx")
excel_file.close()
# Out:
# 1 삼남매맘 추억저장소 20인치 기내용 <b>일본 여행</b> 캐리어 사이즈 크기 로든 추천 https://blog.naver.com/yjy819/223933067312 20250714
# 2 ❤️MIN’s 의 다락방❤️ 20인치 기내용 캐리어 브라이튼 엘론 <b>일본 여행</b> 사용 후기 https://blog.naver.com/gwf21/223909559311 20250624
# 3 여행작가 박은하 일본 오사카 여행 2박3일 일정 <b>일본 여행</b> 경비 아끼는 꿀팁 https://blog.naver.com/neweunha/223892704685 20250608
# 4 한결같은 일상을 특별하게 '◡'✿ 20인치 <b>일본여행</b> 캐리어 브라이튼 로든 기내용 선택 후기 https://blog.naver.com/hej1318200/223911327197 20250625
# 5 빵달의 달슐랭 여행✈️ 여름 <b>일본 여행</b> 나라 당일치기 사슴공원 태교여행 시기 언제 https://blog.naver.com/muse36/223922617273 20250705
# 6 오늘도, 지구 여행 <b>일본 여행</b> 이심 esim 유심사 아이폰 사용법 저렴하게 준비 https://blog.naver.com/be_ok-/223892676907 20250608
# 7 뀰잼뀰팸 쿨키즈 초경량 유모차 : <b>일본 여행</b> 필수템? 결국 후회템 된 사연 https://blog.naver.com/hiloha/223909803483 20250624
# 8 에피의 날마다 좋은하루 첫 <b>일본여행</b> 준비물 체크리스트 해외여행 필수템 주파집 https://blog.naver.com/effy0424/223930598969 20250712
# 9 아롱의 여행일지 <b>일본여행</b> 준비물 체크 리스트 도쿄여행 필수품 꿀팁 정리 https://blog.naver.com/jungdkfma/223909128324 20250623
# ...

# %%
import requests
import pprint #prettier print라는 뜻으로, 결과값을 깔끔하게 출력해주는 lib
import openpyxl

#구조분해할당 튜플 활용
start, num = 1, 0
#엑셀 파일 만들기 위한 변수 지정
excel_file = openpyxl.Workbook()
excel_sheet = excel_file.active
excel_sheet.title = "개봉 영화"
excel_sheet.column_dimensions["B"].width = 30
excel_sheet.column_dimensions["C"].width = 50
excel_sheet.column_dimensions["D"].width = 30
excel_sheet.append(["No", "영화 제목", "줄거리", "개봉일", "평점"])


url = "https://api.themoviedb.org/3/movie/now_playing?language=ko-KR&page=1"

header_params = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJiNDEzOWUwMzE1NWIzMTI1MWYwNWU0MzlmZTE2Y2I2NSIsIm5iZiI6MTc1MjE5NDQwOC41MDg5OTk4LCJzdWIiOiI2ODcwNWQ2OGU1NmM0N2E4NGM2ZTk3YzAiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.ia4INFGtmSdW8FzXdFG3j0bKpcWqdnXei6qdOEKhxVM"
}
res = requests.get(url, headers=header_params)
    
    #requests로 불러온 데이터는 json함수를 활용해 별도의 인코딩 작업 없이 바로 json 형식의 데이터로 출력가능하다
    #test = res.json()
    
    #유효성 검사
if res.status_code == 200:
    data = res.json()
    for item in data["results"]:
        num += 1
        excel_sheet.append([num, item["title"], item["overview"], item["release_date"], item["vote_average"]]) #excel_sheet에 num, title, link값을 넣어줘
        print(num, item["title"], item["overview"], item["release_date"], item["vote_average"])
    else:
        print("Error Code : ", res.status_code)


excel_file.save("movie_현재개봉작.xlsx")
excel_file.close()
# Out:
# 1 가라데 키드: 레전드 서로 다른 세대의 스승 미스터 한(성룡)과 다니엘 라루소(랄프 마치오)가 소년 ‘리’를 중심으로 힘을 합치며 펼쳐지는 무술 성장 드라마. 과거의 철학과 기술을 계승한 두 사부는 삶의 벽에 부딪힌 리에게 가라데의 진정한 의미를 전하며 함께 성장한다. 2025-05-08 7.309
# 2 어쩌다 파트너 동네 치안을 위해 헌신하는 열정 넘치는 단속 요원과 이 지역으로 좌천된 저돌적인 전직 형사. 두 사람이 어쩔 수 없이 한 팀이 되면서 로테르담 거리에 예측 불허의 상황이 펼쳐진다. 2025-07-10 5.63
# 3 슈퍼맨 슈퍼맨은 오늘도 세계 곳곳의 위협에 맞서 싸우지만, 시민들의 반응은 극과 극으로 갈린다. 한편, 렉스 루터는 슈퍼맨을 무너뜨릴 비밀을 손에 넣고 역대 최강의 슈퍼-빌런들과 함께 총 공격에 나선다. 슈퍼맨은 첫 패배와 함께 이들의 계속된 공세에 직면하고 모든 것을 바로잡기 위해 슈퍼독 크립토와 함께 맞서게 되는데... 과연 그는 이 전례 없는 위기에서 다시 날아오를 수 있을까? 2025-07-09 7.4
# 4 발레리나 살해당한 아버지의 복수를 원하는 이브는 전설적인 킬러 존 윅을 배출한 암살자 양성 조직 루스카 로마에서 혹독한 훈련을 거쳐 발레리나이자 킬러로 성장한다. 아버지의 죽음에 얽힌 자들을 쫓던 이브는 루스카 로마를 뛰어넘는 거대한 조직의 정체를 알아차리게 되고, 킬러들의 표적이 된 이브의 눈앞에 존 윅이 나타나는데… 2025-06-04 7.464
# ...

# %%
import requests
import openpyxl

url_base = "https://api.themoviedb.org/3/movie/now_playing"


headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJiNDEzOWUwMzE1NWIzMTI1MWYwNWU0MzlmZTE2Y2I2NSIsIm5iZiI6MTc1MjE5NDQwOC41MDg5OTk4LCJzdWIiOiI2ODcwNWQ2OGU1NmM0N2E4NGM2ZTk3YzAiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.ia4INFGtmSdW8FzXdFG3j0bKpcWqdnXei6qdOEKhxVM"
}

excel_file = openpyxl.Workbook()
excel_sheet = excel_file.active
excel_sheet.column_dimensions["D"].width = 100
excel_sheet.append(["No","개봉일","영화제목","줄거리","평점"])
num,page = 0,1

for index in range(1,6):
    url = f"{url_base}?language=ko-KR&page={page}"
    res = requests.get(url, headers=headers)
    
    if res.status_code == 200:
        data = res.json()
        for item in data["results"] :
            num+=1
            if num>100:
                break
            excel_sheet.append([num,item["release_date"], item["title"], item["overview"], item["vote_average"]])    
            print(num, item["release_date"], item["title"], item["overview"], item["vote_average"])
        page += 1
    else:
        print("Error Code : ", res.status_code)


excel_file.save("movieliset_with_tmdbsite_2.xlsx")
excel_file.close()
# Out:
# 1 2025-05-08 가라데 키드: 레전드 서로 다른 세대의 스승 미스터 한(성룡)과 다니엘 라루소(랄프 마치오)가 소년 ‘리’를 중심으로 힘을 합치며 펼쳐지는 무술 성장 드라마. 과거의 철학과 기술을 계승한 두 사부는 삶의 벽에 부딪힌 리에게 가라데의 진정한 의미를 전하며 함께 성장한다. 7.309
# 2 2025-07-10 어쩌다 파트너 동네 치안을 위해 헌신하는 열정 넘치는 단속 요원과 이 지역으로 좌천된 저돌적인 전직 형사. 두 사람이 어쩔 수 없이 한 팀이 되면서 로테르담 거리에 예측 불허의 상황이 펼쳐진다. 5.63
# 3 2025-07-09 슈퍼맨 슈퍼맨은 오늘도 세계 곳곳의 위협에 맞서 싸우지만, 시민들의 반응은 극과 극으로 갈린다. 한편, 렉스 루터는 슈퍼맨을 무너뜨릴 비밀을 손에 넣고 역대 최강의 슈퍼-빌런들과 함께 총 공격에 나선다. 슈퍼맨은 첫 패배와 함께 이들의 계속된 공세에 직면하고 모든 것을 바로잡기 위해 슈퍼독 크립토와 함께 맞서게 되는데... 과연 그는 이 전례 없는 위기에서 다시 날아오를 수 있을까? 7.4
# 4 2025-06-04 발레리나 살해당한 아버지의 복수를 원하는 이브는 전설적인 킬러 존 윅을 배출한 암살자 양성 조직 루스카 로마에서 혹독한 훈련을 거쳐 발레리나이자 킬러로 성장한다. 아버지의 죽음에 얽힌 자들을 쫓던 이브는 루스카 로마를 뛰어넘는 거대한 조직의 정체를 알아차리게 되고, 킬러들의 표적이 된 이브의 눈앞에 존 윅이 나타나는데… 7.464
# ...
